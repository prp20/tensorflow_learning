# %% [markdown]
# <a href="https://colab.research.google.com/github/prp20/tensorflow_learning/blob/main/CIFAR10_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import itertools
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15):
    """Makes a labelled confusion matrix comparing predictions and ground truth labels.

    If classes is passed, confusion matrix will be labelled, if not, integer class values
    will be used.

    Args:
      y_true: Array of truth labels (must be same shape as y_pred).
      y_pred: Array of predicted labels (must be same shape as y_true).
      classes: Array of class labels (e.g. string form). If `None`, integer labels are used.
      figsize: Size of output figure (default=(10, 10)).
      text_size: Size of output figure text (default=15).

    Returns:
      A labelled confusion matrix plot comparing y_true and y_pred.

    Example usage:
      make_confusion_matrix(y_true=test_labels, # ground truth test labels
                            y_pred=y_preds, # predicted labels
                            classes=class_names, # array of class label names
                            figsize=(15, 15),
                            text_size=10)
    """
    # Create the confustion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]  # normalize it
    n_classes = cm.shape[0]  # find the number of classes we're dealing with

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])

    # Label the axes
    ax.set(title="Confusion Matrix",
           xlabel="Predicted label",
           ylabel="True label",
           xticks=np.arange(n_classes),  # create enough axis slots for each class
           yticks=np.arange(n_classes),
           xticklabels=labels,  # axes will labeled with class names (if they exist) or ints
           yticklabels=labels)

    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j] * 100:.1f}%)",
                 horizontalalignment="center",
                 color="white" if cm[i, j] > threshold else "black",
                 size=text_size)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['Tshirt', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_data_norm = train_data/255.0
test_data_norm = test_data/255.0

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys
# current = os.path.dirname(os.path.dirname(os.path.realpath(__file__)))
# sys.path.append(current)
# from utils import make_confusion_matrix, plot_random_images_using_predictions, plot_random_images, plot_loss_curves

train_data, train_labels, test_data, test_labels = None, None, None, None
classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

(train_data, train_labels), (test_data, test_labels) = cifar10.load_data()
# print(f" Train data is :{train_data[0]} \n")
# print(f" Train label is :{train_labels[0][0]} \n")
print(f" Train data shape :{train_data[0].shape} \n")
print(f" Train label shape is :{train_labels[0].shape} \n")
# print(train_labels.squeeze())

# Visualise random data
# for i in range(20):
#     plot_random_images(train_data, train_labels.squeeze(), classes)

# normalize train and test data
train_data_norm = train_data/255.0
test_data_norm = test_data/255.0
train_labels = train_labels.squeeze()
test_labels = test_labels.squeeze()

# define base model
# initialise random seed
tf.random.set_seed(42)

# Define the model
model_1 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
    tf.keras.layers.Dense(40, activation='relu'),
    tf.keras.layers.Dense(40, activation='relu'),
    tf.keras.layers.Dense(10, activation=tf.keras.activations.softmax)
], name = 'model_CIFAR1_1')

# Compile the model
model_1.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.0002),
                metrics=['accuracy'])

# Learning rate Scheduler
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10 ** (epoch/20))
file_path = f"saved_models/{model_1.name}"
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=file_path, monitor='val_accuracy', save_best_only=True)
# Fit the model
history_1 = model_1.fit(train_data_norm,
                        train_labels,
                        epochs=100,
                        validation_data=(test_data_norm, test_labels),
                        callbacks=[model_checkpoint])

# Plot loss versus Epochs Curve
# plot_loss_curves(history_1)

# Evaluate the model
model_1.evaluate(test_data_norm, test_labels)

# Plot the Confusion Matrx
y_preds = model_1.predict(test_data_norm)
make_confusion_matrix(y_true=test_labels,
                      y_pred=tf.argmax(y_preds, axis=1),
                      classes=classes,
                      figsize=(20, 20),
                          text_size=10)
# Out:
#  Train data shape :(32, 32, 3)
#
#  Train label shape is :(1,)
#
# Epoch 1/100
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.9766 - accuracy: 0.2831 - val_loss: 1.8498 - val_accuracy: 0.3338
# Epoch 2/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.8029 - accuracy: 0.3595 - val_loss: 1.7680 - val_accuracy: 0.3690
# Epoch 3/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.7503 - accuracy: 0.3768 - val_loss: 1.7385 - val_accuracy: 0.3840
# Epoch 4/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.7163 - accuracy: 0.3911 - val_loss: 1.6919 - val_accuracy: 0.4013
# Epoch 5/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6827 - accuracy: 0.4041 - val_loss: 1.6779 - val_accuracy: 0.4096
# Epoch 6/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6543 - accuracy: 0.4149 - val_loss: 1.6527 - val_accuracy: 0.4152
# Epoch 7/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6354 - accuracy: 0.4231 - val_loss: 1.6387 - val_accuracy: 0.4212
# Epoch 8/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.6141 - accuracy: 0.4318 - val_loss: 1.6163 - val_accuracy: 0.4260
# Epoch 9/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5995 - accuracy: 0.4364 - val_loss: 1.6227 - val_accuracy: 0.4225
# Epoch 10/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5811 - accuracy: 0.4434 - val_loss: 1.5976 - val_accuracy: 0.4330
# Epoch 11/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5681 - accuracy: 0.4479 - val_loss: 1.5864 - val_accuracy: 0.4340
# Epoch 12/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5566 - accuracy: 0.4517 - val_loss: 1.5779 - val_accuracy: 0.4386
# Epoch 13/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5456 - accuracy: 0.4548 - val_loss: 1.5721 - val_accuracy: 0.4422
# Epoch 14/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5361 - accuracy: 0.4588 - val_loss: 1.5843 - val_accuracy: 0.4405
# Epoch 15/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5263 - accuracy: 0.4618 - val_loss: 1.5782 - val_accuracy: 0.4408
# Epoch 16/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5200 - accuracy: 0.4651 - val_loss: 1.5516 - val_accuracy: 0.4512
# Epoch 17/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5119 - accuracy: 0.4682 - val_loss: 1.5658 - val_accuracy: 0.4501
# Epoch 18/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.5066 - accuracy: 0.4692 - val_loss: 1.5523 - val_accuracy: 0.4522
# Epoch 19/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4979 - accuracy: 0.4716 - val_loss: 1.5564 - val_accuracy: 0.4515
# Epoch 20/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4911 - accuracy: 0.4745 - val_loss: 1.5324 - val_accuracy: 0.4617
# Epoch 21/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4872 - accuracy: 0.4742 - val_loss: 1.5424 - val_accuracy: 0.4550
# Epoch 22/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4787 - accuracy: 0.4775 - val_loss: 1.5353 - val_accuracy: 0.4587
# Epoch 23/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4760 - accuracy: 0.4794 - val_loss: 1.5304 - val_accuracy: 0.4635
# Epoch 24/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4725 - accuracy: 0.4811 - val_loss: 1.5411 - val_accuracy: 0.4616
# Epoch 25/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4675 - accuracy: 0.4827 - val_loss: 1.5278 - val_accuracy: 0.4596
# Epoch 26/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4636 - accuracy: 0.4834 - val_loss: 1.5219 - val_accuracy: 0.4609
# Epoch 27/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4565 - accuracy: 0.4844 - val_loss: 1.5124 - val_accuracy: 0.4653
# Epoch 28/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4541 - accuracy: 0.4867 - val_loss: 1.5159 - val_accuracy: 0.4625
# Epoch 29/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4513 - accuracy: 0.4856 - val_loss: 1.5282 - val_accuracy: 0.4644
# Epoch 30/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4470 - accuracy: 0.4877 - val_loss: 1.5188 - val_accuracy: 0.4666
# Epoch 31/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4420 - accuracy: 0.4903 - val_loss: 1.5356 - val_accuracy: 0.4511
# Epoch 32/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.4365 - accuracy: 0.4936 - val_loss: 1.4994 - val_accuracy: 0.4728
# Epoch 33/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4358 - accuracy: 0.4935 - val_loss: 1.5028 - val_accuracy: 0.4748
# Epoch 34/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4330 - accuracy: 0.4950 - val_loss: 1.5000 - val_accuracy: 0.4715
# Epoch 35/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4304 - accuracy: 0.4937 - val_loss: 1.5005 - val_accuracy: 0.4692
# Epoch 36/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4244 - accuracy: 0.4975 - val_loss: 1.5067 - val_accuracy: 0.4683
# Epoch 37/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4232 - accuracy: 0.4969 - val_loss: 1.4968 - val_accuracy: 0.4700
# Epoch 38/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4192 - accuracy: 0.4987 - val_loss: 1.5064 - val_accuracy: 0.4663
# Epoch 39/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4160 - accuracy: 0.4991 - val_loss: 1.4918 - val_accuracy: 0.4766
# Epoch 40/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4137 - accuracy: 0.5009 - val_loss: 1.5060 - val_accuracy: 0.4679
# Epoch 41/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.4091 - accuracy: 0.5013 - val_loss: 1.4903 - val_accuracy: 0.4778
# Epoch 42/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4062 - accuracy: 0.5022 - val_loss: 1.4994 - val_accuracy: 0.4726
# Epoch 43/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4061 - accuracy: 0.5017 - val_loss: 1.5062 - val_accuracy: 0.4675
# Epoch 44/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4017 - accuracy: 0.5032 - val_loss: 1.5181 - val_accuracy: 0.4644
# Epoch 45/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.4008 - accuracy: 0.5047 - val_loss: 1.4830 - val_accuracy: 0.4802
# Epoch 46/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3972 - accuracy: 0.5043 - val_loss: 1.4963 - val_accuracy: 0.4716
# Epoch 47/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3952 - accuracy: 0.5064 - val_loss: 1.4798 - val_accuracy: 0.4765
# Epoch 48/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3948 - accuracy: 0.5073 - val_loss: 1.4937 - val_accuracy: 0.4769
# Epoch 49/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3888 - accuracy: 0.5092 - val_loss: 1.4857 - val_accuracy: 0.4740
# Epoch 50/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3884 - accuracy: 0.5096 - val_loss: 1.4905 - val_accuracy: 0.4763
# Epoch 51/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3850 - accuracy: 0.5086 - val_loss: 1.4876 - val_accuracy: 0.4798
# Epoch 52/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3872 - accuracy: 0.5105 - val_loss: 1.5012 - val_accuracy: 0.4738
# Epoch 53/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3820 - accuracy: 0.5095 - val_loss: 1.5178 - val_accuracy: 0.4677
# Epoch 54/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3805 - accuracy: 0.5128 - val_loss: 1.5025 - val_accuracy: 0.4728
# Epoch 55/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3753 - accuracy: 0.5123 - val_loss: 1.4919 - val_accuracy: 0.4763
# Epoch 56/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3742 - accuracy: 0.5136 - val_loss: 1.4896 - val_accuracy: 0.4773
# Epoch 57/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3722 - accuracy: 0.5148 - val_loss: 1.4997 - val_accuracy: 0.4743
# Epoch 58/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3729 - accuracy: 0.5124 - val_loss: 1.4840 - val_accuracy: 0.4792
# Epoch 59/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3695 - accuracy: 0.5155 - val_loss: 1.4837 - val_accuracy: 0.4806
# Epoch 60/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3676 - accuracy: 0.5170 - val_loss: 1.4925 - val_accuracy: 0.4797
# Epoch 61/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3658 - accuracy: 0.5176 - val_loss: 1.4987 - val_accuracy: 0.4794
# Epoch 62/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3648 - accuracy: 0.5172 - val_loss: 1.5041 - val_accuracy: 0.4735
# Epoch 63/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3642 - accuracy: 0.5159 - val_loss: 1.4880 - val_accuracy: 0.4790
# Epoch 64/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3594 - accuracy: 0.5188 - val_loss: 1.4827 - val_accuracy: 0.4782
# Epoch 65/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3577 - accuracy: 0.5190 - val_loss: 1.4949 - val_accuracy: 0.4783
# Epoch 66/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3572 - accuracy: 0.5205 - val_loss: 1.4941 - val_accuracy: 0.4797
# Epoch 67/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3548 - accuracy: 0.5185 - val_loss: 1.4850 - val_accuracy: 0.4737
# Epoch 68/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3542 - accuracy: 0.5219 - val_loss: 1.4774 - val_accuracy: 0.4873
# Epoch 69/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3507 - accuracy: 0.5217 - val_loss: 1.4799 - val_accuracy: 0.4848
# Epoch 70/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3494 - accuracy: 0.5205 - val_loss: 1.4937 - val_accuracy: 0.4805
# Epoch 71/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3485 - accuracy: 0.5232 - val_loss: 1.4845 - val_accuracy: 0.4824
# Epoch 72/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3467 - accuracy: 0.5239 - val_loss: 1.5182 - val_accuracy: 0.4727
# Epoch 73/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3428 - accuracy: 0.5250 - val_loss: 1.4804 - val_accuracy: 0.4814
# Epoch 74/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3451 - accuracy: 0.5218 - val_loss: 1.4808 - val_accuracy: 0.4834
# Epoch 75/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3425 - accuracy: 0.5239 - val_loss: 1.4891 - val_accuracy: 0.4839
# Epoch 76/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3390 - accuracy: 0.5259 - val_loss: 1.4848 - val_accuracy: 0.4802
# Epoch 77/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3392 - accuracy: 0.5260 - val_loss: 1.5044 - val_accuracy: 0.4778
# Epoch 78/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3385 - accuracy: 0.5265 - val_loss: 1.4769 - val_accuracy: 0.4814
# Epoch 79/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3373 - accuracy: 0.5255 - val_loss: 1.4693 - val_accuracy: 0.4853
# Epoch 80/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3358 - accuracy: 0.5270 - val_loss: 1.4771 - val_accuracy: 0.4842
# Epoch 81/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3335 - accuracy: 0.5276 - val_loss: 1.4775 - val_accuracy: 0.4849
# Epoch 82/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3330 - accuracy: 0.5280 - val_loss: 1.4810 - val_accuracy: 0.4805
# Epoch 83/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3280 - accuracy: 0.5290 - val_loss: 1.4758 - val_accuracy: 0.4877
# Epoch 84/100
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.3279 - accuracy: 0.5288 - val_loss: 1.4732 - val_accuracy: 0.4894
# Epoch 85/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3275 - accuracy: 0.5295 - val_loss: 1.4811 - val_accuracy: 0.4827
# Epoch 86/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3266 - accuracy: 0.5309 - val_loss: 1.4920 - val_accuracy: 0.4814
# Epoch 87/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3251 - accuracy: 0.5302 - val_loss: 1.5044 - val_accuracy: 0.4780
# Epoch 88/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3240 - accuracy: 0.5329 - val_loss: 1.5128 - val_accuracy: 0.4766
# Epoch 89/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3213 - accuracy: 0.5313 - val_loss: 1.4869 - val_accuracy: 0.4836
# Epoch 90/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3208 - accuracy: 0.5314 - val_loss: 1.4847 - val_accuracy: 0.4859
# Epoch 91/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3195 - accuracy: 0.5330 - val_loss: 1.4887 - val_accuracy: 0.4826
# Epoch 92/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3187 - accuracy: 0.5322 - val_loss: 1.5610 - val_accuracy: 0.4620
# Epoch 93/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3158 - accuracy: 0.5328 - val_loss: 1.4845 - val_accuracy: 0.4830
# Epoch 94/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3152 - accuracy: 0.5336 - val_loss: 1.5053 - val_accuracy: 0.4728
# Epoch 95/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3122 - accuracy: 0.5354 - val_loss: 1.5314 - val_accuracy: 0.4660
# Epoch 96/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3132 - accuracy: 0.5335 - val_loss: 1.4850 - val_accuracy: 0.4792
# Epoch 97/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3136 - accuracy: 0.5351 - val_loss: 1.5231 - val_accuracy: 0.4691
# Epoch 98/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3100 - accuracy: 0.5338 - val_loss: 1.4804 - val_accuracy: 0.4888
# Epoch 99/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3110 - accuracy: 0.5335 - val_loss: 1.4937 - val_accuracy: 0.4803
# Epoch 100/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.3096 - accuracy: 0.5353 - val_loss: 1.4863 - val_accuracy: 0.4868
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4863 - accuracy: 0.4868

# %%
y_preds = model_3.predict(test_data_norm)
tf.argmax(y_preds, axis=1)
# Out:
# <tf.Tensor: shape=(10000,), dtype=int64, numpy=array([9, 2, 1, ..., 3, 1, 5])>

# %%
make_confusion_matrix(test_labels, tf.argmax(y_preds, axis=1), class_names, figsize=(15,15), text_size=10)
